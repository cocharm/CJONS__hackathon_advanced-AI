# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import random
import os
import pandas as pd
from transformers import AutoConfig
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import torch
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import StepLR
from google.colab import drive
import numpy as np

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# 새로운 리뷰 데이터 로드
predicted_reviews_df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/skin_toner.csv')
predicted_reviews_df.rename(columns={
    'label': 'sentiment',
    'review': 'txt',

}, inplace=True)

# %%
predicted_reviews_df['review'] = predicted_reviews_df['txt'].str.replace('\n', ' ').replace('\r', ' ')

# %%
tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/61.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/467 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/263k [00:00<?, ?B/s]

# %%
model = AutoModelForSequenceClassification.from_pretrained("monologg/koelectra-base-v3-discriminator", num_labels=2)  # 감성 라벨이 긍정/부정 두개이므로 num_labels=2으로 설정
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/452M [00:00<?, ?B/s]
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
class ReviewDataset(Dataset):
    def __init__(self, data, tokenizer, max_len):
        self.tokenizer = tokenizer
        self.max_len = max_len

        # 토큰화한 길이를 계산하고, max_len보다 큰 데이터를 필터링합니다.
        self.data = data[data['txt'].apply(lambda x: len(self.tokenizer.tokenize(x)) < self.max_len)]

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        text = row['txt']
        label = row['sentiment']

        inputs = self.tokenizer.encode_plus(
            text,
            truncation=True,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt'
        )

        return {
            'ids': inputs['input_ids'].flatten(),
            'mask': inputs['attention_mask'].flatten(),
            'targets': torch.tensor(label, dtype=torch.long)
        }

    def __len__(self):
        return len(self.data)

# %%
# 로더 준비
predicted_dataset = ReviewDataset(predicted_reviews_df, tokenizer, max_len=512)
predicted_loader = DataLoader(predicted_dataset, batch_size=16, shuffle=False)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (621 > 512). Running this sequence through the model will result in indexing errors

# %%
model.load_state_dict(torch.load('/content/drive/My Drive/Colab Notebooks/L25_drop02_10epoch_sche0_4_best_model.pth'))
model.eval()
preds = []
for batch in predicted_loader:
    input_ids = batch['ids']
    attention_mask = batch['mask']
    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
    preds.extend(torch.argmax(outputs.logits, axis=-1).tolist())

# %%
model = AutoModelForSequenceClassification.from_pretrained("monologg/koelectra-base-v3-discriminator", num_labels=2)  # 감성 라벨이 긍정/부정 두개이므로 num_labels=2으로 설정
# Out:
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
max_len = 512
filtered_data =predicted_reviews_df[predicted_reviews_df['txt'].apply(lambda x: len(tokenizer.tokenize(x)) < max_len)]
results_df = pd.DataFrame({'name': filtered_data['name'], 'review': filtered_data['txt'], 'sentiment': preds})

# %%
# 긍정적인 리뷰와 부정적인 리뷰 선택
positive_reviews = results_df[results_df['sentiment'] == 1]
negative_reviews = results_df[results_df['sentiment'] == 0]

# %%
# 각 상품명에 따라 긍정적인 리뷰와 부정적인 리뷰 그룹화
positive_grouped = positive_reviews.groupby('name')
negative_grouped = negative_reviews.groupby('name')

# %%
# 각 그룹을 출력하고, 별도의 파일로 저장
for name, group in positive_grouped:
    print(f"Product name: {name}")
    print("Positive reviews:")
    print(group)
    #group.to_csv(os.path.join( f'{name}_positive_reviews.csv'), index=False)

for name, group in negative_grouped:
    print(f"Product name: {name}")
    print("Negative reviews:")
    print(group)
    #group.to_csv(os.path.join( f'{name}_negative_reviews.csv'), index=False)
# Out:
# Product name: [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(350ML+350ML리필)
# Positive reviews:
#                                                  name  \
# 4   [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 9   [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 17  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 20  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 40  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 50  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 51  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 52  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 53  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 54  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 55  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 56  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 57  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 58  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 59  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 60  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 61  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 62  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 64  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 66  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 67  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 68  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 69  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 70  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 71  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 72  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 73  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 74  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 75  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 76  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 77  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 78  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 79  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 80  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 81  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 82  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 83  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 84  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 85  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 86  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 87  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 88  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 89  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 90  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 91  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 92  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 93  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 94  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 95  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 96  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 97  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 98  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 99  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
#
#                                                review  sentiment
# 4   좋아요 정말 몇 병째 공병템인지 모르겠어요 그냥 물같은 느낌이지만 바르면 안 당기고...          1
# 9   아누아 어성초 토너 진짜 귀에 딱지가 얹을 정도로 이름을 너무 많이 들어봤어요! 이...          1
# 17      꼭 테스트해보고 사세요! 혹은 각질제거 성분에 자극을 느끼시는분들께는 비추천입니다          1
# 20          여드름 진정으로 쓰기 좋아요... 토너팩 하고 자고 일어나면 맨들맨들 해짐          1
# 40            여드름 상처에 바르니 따갑다고 하는데 상처 없는 지성페부에는 자극없어요          1
# 50  마침 토너가 필요했는데 인기가 많은 것 같길래 구매해봤습니다! 기획이라 1+1 으로...          1
# 51                   어성초성분이잘맞아서 몇통째사용하고있는데\n닦토하기도좋아요~          1
# 52                 성분도좋고 촉촉해서 닦토로도잘쓰구있어요~\n만족하는제품입니다~          1
# 53        진정에좋고 순해요~ 용량도커서닦토로쓰기도좋아요~어성초성분이잘맞아서 잘쓰구있어요          1
# 54              아누아 어성초토너만 구매해요!\n토너용량도 많고, 배송도 빠르네요!          1
# 55               항상구매하는 아누아토너입니다!\n이번 배송은 엄청 빨리도착했어요!          1
# 56  올영에서 할인하고 있어서 구매해온 토너에요. 엑소 수호토너로 유명합니다!! 아누아 ...          1
# 57  USER INFO🔍\n30대/남성/악지성~지성/발효OK, 티트리NO/모공, 화농성 ...          1
# 58  그나마 닦토 중에 젤 덜 건조했던 아이였던거 같네요\n리뷰 레고레고\n\n제 피부는...          1
# 59  중학생 딸 이마 좁쌀 여드름과 피지가 고민되어 어성초 77% 수딩 토너를 구입하게 ...          1
# 60  USER INFO🔍\n30대/남성/악지성~지성/발효OK, 티트리NO/모공, 화농성 ...          1
# 61  😊 제 피부는 이마에는 좁쌀이 있고, 볼에는 마스크트러블과 붉은기가 있는 피부입니다...          1
# 62  좁쌀 여드름에 아누아 제품 말해 뭐해요. 입만 아프죠!!\n아누아 토너 제품은 올영...          1
# 64  🙂총평: 토너보다 앰플 추천! 토너는 진정, 보습에 좋았고 앰플도 진정 보습에 더더...          1
# 66  💙 토너 바꿀때가 되서 뭐 살까 고민하다가 유투버가 추천 해줘서 구매했어요 !!! ...          1
# 67  좁쌀 여드름에 좋다고해서 구매했어요! 저는 수분 부족형 지성 피부에 민감성까지 함께...          1
# 68  사람들이 엄청 극찬하길래 저도 마침 토너 필요해서 사봤습니다 저한테는 크게 메리트 ...          1
# 69  이 제품이 유투브에서 좋다고 엄청 유명하더라고요 그대를 해서 그런지 딱히 효과는 없...          1
# 70  좁쌀여드름이 자주 올라오는 편이라 좁쌀여드름에 좋다는 아누아 어성초 77토너를 한번...          1
# 71  마스크 때문에 볼과 턱이 예민해져서 트러블이 많이 올라오는데 화장솜에 토너 충분히 ...          1
# 72  💞아누아 어성초 77% 토너\n\n트러블 피부는 아닌데 어성초가 아무래도 진정에 도...          1
# 73  워낙 순하기로 유명한 제품이라 믿고 구매를 해봤는데 제가 피부가 거칠어져서 뭔가 자...          1
# 74  🤍아누아 어성초 77 수딩 토너 후기🤍\n\n- 진정에 좋다고 유명해 궁금해서 세일...          1
# 75  자극없이 순한 토너는 아누아가 최고에요. 더운 여름날 피부가 엄청 붉어지고 관리하기...          1
# 76  💕한달사용후기💕\n저는 피부에 크림이나 뭘 바르면 오히려 피부에 트러블이 나서 \n...          1
# 77       예민한 피부인데도 불구하고 너무 잘 맞아서 좋아요! 여름 철에 사용하면 최고👍👍          1
# 78  여러 통째 사용중인 제품입니다! 민감성 피부인데 트러블 진정에도 좋고 물제형이라 가...          1
# 79  워터리한 토너 찾으시면 추천드려요!!\n닦토 흡토 팩토에 모두 잘맞고 무향무색에 진...          1
# 80                  항상 쓰는 토너인데 환경 생각해서 리필세트로 나오는게 좋네요          1
# 81  피부 진정에 좋다 하여 기대가 됩니다~ \n자극 없는 순한 토너라 크게 뒤집어질 일...          1
# 82  한 다섯통째 ..? 쓰고있어요. 코로나때 피부 뒤집아지기 시작하고 아누아 어성초 괜...          1
# 83      아이가 여드름이 나사 1년넘게 시용중입니다.진전효과에 좋다고해서 꾸준히 쓰고있어요          1
# 84  매번 재구매입니다..✌️✌️너무 만족합니다 집에 있어도 세일 하면 미리 쟁겨놔요.강추🥰🥰          1
# 85  아누아 1년 전에 써보고 계속 꾸준히 쓰는 중이에요\n순해서 좋고 아침 저녁으로 맨...          1
# 86  수술 후 잘 씻을 수 없어서 피부가 한번 뒤집혔었는데 요 토너 사용하면서 많이 진정...          1
# 87            자극없이 순해서 여러번 레이어드해서 발르면 피부가 촉촉해지는 기분이에요          1
# 88  아누아 앰플이랑 데일리 로션도 같이 구매했는데 너무 좋아요 이거 쓰고 피부가 쫀쫀해...          1
# 89                어성초 가 맞는 피부인데요 진정에도 좋고 여드름에 정말 좋ㅇ아요          1
# 90  지금 사이즈별로 몇통째 사용중인니 모르겠어요 너무 잘 맞아서 이번에 이거 산거도 이...          1
# 91       자극없이 순해요 피부 진정에 가장 좋은 것 같아요 진짜 이것만 사용하는 중이에요          1
# 92  늘 쓰는 스킨이에요 준면 픽\n정착해서 쓰는 사람둘도 많은데 리필팩만 따로 판매했으...          1
# 93      피부 진정에 좋운 것 같고 순하고 자극적이지 않아서 민감성 피부도 좋을 것 같아요          1
# 94  몇통째 비운건지 모르는 재재재구매템!!\n민감한 피부에 자극없이 기초케어 하기 좋아...          1
# 95       항상 쓰고 있는 제품이에요ㅎ 너무 끈적이지 않고 트러블 없이 잘 사용하고 있어요          1
# 96         추천받아서 대용량할인들어가 구매해봤는데 블랙헤드에도 좋다고해서구매해봤어요ㅎㅎ          1
# 97                   아침에는 토리든쓰고\n저녁에는 어성초쓰는데 촉촉하니 좋아요          1
# 98  아누아 어성초 토너 완전 인생템이에요 맞는 토너 찾고 정착한지 꽤 됐는데 이거 만큼...          1
# 99  자극없이 너무 순하고 여드름 뾰루지도 거의 안올라와서 너무 좋아요!!쓰고나서 땡김도...          1
# Product name: [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (+화장솜 60매 증정)
# Positive reviews:
#                                                   name  \
# 116  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 121  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 122  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 136  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 137  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 138  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 139  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 140  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 141  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 142  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 143  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 144  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 145  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 146  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 147  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 149  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 150  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 151  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 152  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 153  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 154  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 155  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 156  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 157  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 159  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 160  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 161  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 162  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 163  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 164  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 165  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 166  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 167  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 168  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 169  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 170  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 171  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 172  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 173  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 174  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 175  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 176  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 177  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 178  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 179  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 180  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 181  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 182  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 183  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 184  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
# 185  [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (...
#
#                                                 review  sentiment
# 116  물 같은데 얼굴에 바르면 흐르지 않고 흡수가 잘되서 바르기 편하고 끈적이지 않아서 ...          1
# 121  세럼은 이미 50미리 용기하나 비우고 큰걸 사서 쓰는중입니다.\n이번 겨울은 토리든...          1
# 122  순하고 촉촉하고(오래안가는) 보이는 이미지 패키징 그대로의 느낌이네요 ㅋㅋ\n물제형...          1
# 136  그냥 무-난한 물토너에용 기획좋고 용량도 괜찮고 해서 구매했어용 저는 닦토로 써주고...          1
# 137  처음에는 쓸 때 특별히 좋은지 몰랐는데\n막상 다 쓰고 다른거 쓰다보니까 아!\n이...          1
# 138  한달이상 사용 후기: 지성에겐 적당, 건성에겐 건조할 수도 있는 수분 토너\n제 리...          1
# 139  __피부타입__\n트러블성 민감성피부에 홍조도 있고, 안맞는 제품을 사용하면 바로 ...          1
# 140  스킨팩용으로 양이 넉넉한 스킨 찾다가 저번에 구매했던 토리든 수분크림이 순하게 발렸...          1
# 141  크게 기대하지 않고 구매한 제품인데 의외로 괜찮았습니다.\n보습에는 역시 히알루론만...          1
# 142  정말 수분 그자체에요 유분기 끈적임 이런거 전혀 하나도 없고 오직 100퍼센트 수분...          1
# 143       100미리나 더 줘서 좋더라고요 세일도 하고요 .무난하게 쓰기 좋아요 추천합니다          1
# 144  지설 피부에도 괜찮은 제품입니다. 여드름이 종종 나 고민인 아들이 쓸만한 게 뭐가 ...          1
# 145  순하고 끈적이지 않지만 보습이 잘되서 구매하게되었어요!! 닦토와 수분충전을 같이 할...          1
# 146  자극없이 순한 물스킨입니다. 근데 너무 물이라 흡수가 오래걸려서 손으로 찹찹 자주해...          1
# 147  그냥 이 토너를 한 마디로 표현하자면 무난템인것 같아요!\n말 그대로 그냥 무난해요...          1
# 149  엄청 순한거 같아요~ 사실 바르자 마자 보습력 최고다 이거 보다는 시원하고 여름에 ...          1
# 150  토리든 토너 쓰다가 대용량 할인하길래\n구매해봤어요!\n\n첨엔 너무 무거워서 팔목...          1
# 151  - 제형: 물처럼 맑고 묽은, 가벼운 제형이에요. \n- 향: 거의 없어요. 저 정...          1
# 152  토리든은 앰플로 처음 접했어요! 앰플 한창 세일했을때 반신반의하는 마음으로썼었는데 ...          1
# 153  스킨느낌인데 사용하면 보습시되는거같아서 촉촉해요\n흡수가 살짝느려서 바르고 기다린후...          1
# 154  무난하게 잘 사용했어요. 이제 거의 다 써서 다른 토너 샀는데 작은 용량은 갖고 다...          1
# 155          촉촉하고 좋아요 \n피부가 예민한 편임에도 불구하고 붉어짐 없이 산뜻하네요          1
# 156  닦토용으로 사용한지 꽤 됐는데 순하고\n수분감도 좋고 무난하게 사용하기 좋아요\n대...          1
# 157  스프레이 공병에 담에 세수하자마자 사용함.\n건조함에 좋고 흡수력도 좋아 여러번 레...          1
# 159  토리든 세럼이랑 같이 사용하려고 구매했어요 토너 패드를 만들어 사용해서 그런지 그냥...          1
# 160  총평: 속건조 잡기에는 아쉬우나 자극없이 여름에 가볍게 사용하기 좋은 토너\n제 리...          1
# 161  다이브인 토너 1N년째 사용중인 찐 후기 말씀 드릴게요ㅎㅎ\n\n요즘 독도토너도 많...          1
# 162  10통째 쓴 찐리뷰❤️\n제가 쓰면서도 리뉴얼이됐는데..\n이번에 또?! 리뉴얼이 ...          1
# 163               가족 모두 영입 ! 짝꿍에 이어 동생도 구매 했어요 좋아요 !!!          1
# 164  히알루론산성분 피부에 너무 잘 맞는데 흐르는 토너 유분기없는토더중에서도 수분감충분하...          1
# 165  무난해서 짝꿍 한테도 추천해주고 어제 구매하고옴 ㅋㅋ\n좋아요 자극 없고 수분감 가...          1
# 166  전부터 이 제품 구성도 좋고 가격도 좋아서 사고 싶어서 올리브영 앱 장바구니에 담고...          1
# 167  나이들며토너의중요성을깨닫고대용랑알아보던중 예전부터관심있던토리든이좋을거같아 세럼-수딩...          1
# 168  크게 기대하지 않고 구매한 제품인데 의외로 괜찮았습니다.\n요것조것 써봐도\n순수한...          1
# 169  여름엔 워터 제형 스킨이 좋기 때문에 대용량으로 막 잘 쓰고 있어요~~ 촉촉함보다는...          1
# 170  수부지라서 수분 앰플듀 사용중인데 토너로 비슷하게 써보려고 구매했어요! \n사실 토...          1
# 171           항상 쓰는 토너 건성에 좋아요 !! 수분 가득 해서 화장 잘 먹고 좋네요          1
# 172  남녀노소 토너 추천템으로 좋아요! 수분에 집중된 제품이라 피부 뒤집어질 일도 없고 ...          1
# 173                  토너로 쓰기 무난해요 진정되고 생각보다 촥촥해서 좋아용 ㅎㅎ          1
# 174  ❣️ 피부 타입 ❣️\n수부지, 속건조 극심했음(과거형!)\n\n\n🔍 제형, 향 ...          1
# 175              토리든 잘 사용해요 히알루로산이 많이든 상품라인이있어서 넘나 좋아요          1
# 176  자극 없는 물토너 언제나 쓰기 좋은 거 같아요 저는 복합성인데 한번은 너무 가볍고 ...          1
# 177  스킨용으로 샀는데 닦토용으로 더 좋을거 같아요~ \n여름이라 가볍게 수분 충전하기에...          1
# 178  어릴땐스킨케어에크게신경안썼는데 나이들며깨끗하고맑은피부가얼마나중요한지새삼느껴요. 첫순...          1
# 179  몇 통째 사용하고 있는지 모릅니다. 지금은 100ML통에 덜어서 사용하고 있습니다....          1
# 180  저분자 히아루론산 토너 옛날부터 사용했는데\n이젠 다양한 브랜드에서 출시되서\n토리...          1
# 181  1일 1팩 데일리로 사용하는 토너팩 \n피부자극 안느껴지고 토너에 솜 푹 절여서 붙...          1
# 182  세안하고 수분충전해줄 토너가 필요해 구매했어요!\n\n진짜 그냥 물같은 제형이여서 ...          1
# 183  몇통째 사용했던 제품인지 셀수가 없네요~\n가성비 최고이고 여름에 사용하기 너무 가...          1
# 184       수분가득 제 인생토너🩵 토리든 없인 못 살아요 사계절 내내 너무 잘 쓰고 있어용          1
# 185           닦토, 흡토하기 좋아요~ 300미리쓰다가 500미리 대용량 나오니 좋네오          1
# Product name: [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# Positive reviews:
#                                           name  \
# 312  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 314  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 315  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 319  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 325  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 327  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 337  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 338  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 339  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 341  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 342  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 343  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 344  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 345  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 347  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 348  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 349  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 350  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 351  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 352  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 353  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 354  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 355  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 358  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 360  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 361  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 362  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 363  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 364  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 365  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 366  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 368  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 369  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 370  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 371  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 372  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 373  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 374  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 375  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 376  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 377  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 380  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 381  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 382  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 383  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 384  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
# 385  [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정)
#
#                                                 review  sentiment
# 312  ✔️뷰티 유튜버가 한 번쯤 추천한 결광토너 좋을까❓\n\n✔️구매이유\n뷰티 유튜버...          1
# 314  광고도 많고 리뷰도 많아서 기대를 많이하고 산 제품이에요! 결론부터 말하자면 저는 ...          1
# 315  아기낳고 2년째 겨울마다 \n얼굴은 빨갛게 되고 주름질 정도로 건조해지고,\n 몸 ...          1
# 319  일단 넘버즈? 이 제품은 스텝2 스킨 먼저 써봤는데여\n핑크색이여! 홪장할때 아침에...          1
# 325  ✨넘버즈인 3번 결광가득에센스 토너✨\n이제품은 워낙 유튜브나 sns에서 많이봐서 ...          1
# 327             보통의 토너.\n약한 영양감있는 콧물 제형.\n거의 무향에 가까웠다.          1
# 337                 그냥 크게 좋은 거 모르겠고 나쁜 것도 잘 모르겠어요!무난해요          1
# 338  넘버즈인은 전제품이 다 만족스러운거같아요~\n3번 결세럼 먼저 써보고 너무 좋아서 ...          1
# 339  피부 상태 괜찮을 때 쓰는 토너입니다. 영양감 가득한 느낌이긴 한데 피부 진정이 필...          1
# 341                  파부결 정리용으러 젛아여 나름 그래도 토너는 어성초77이 짱          1
# 342                   진짜 괜찮네용 만족합니당! 매끈매끈해쟈요 젛아요 향도괜탆두          1
# 343           같이 들어있던 화장솜은 그냥 그렇지만\n토너는 자극 없이 아주 좋아요!!          1
# 344  요 제품 뭔가 피부가 쫀쫀해지고 부드러워지는 기분이 들어요. 넘버즈인 제품들 다 왠...          1
# 345  아침 출근 전 급하게 사용할 때는 별효과가 없는 것 같아서 이건 아니다라고 생각했는...          1
# 347  토너 리필은 있는데 토너를 잃어버려서 리필을 못하는 사람이 되어버려.. 넘버즈인 3...          1
# 348     피부에 자극없고 순해요. 제형은 토너와 에센스 섞인 느낌이고 보습력 있어서 촉촉해요          1
# 349             남버즈인이 하두 유명해서 이제야 구매해바요 한달 뒤 써보고 리뷰할게요          1
# 350                 향이 기가막혀요. 세럼만큼 감동은 덜한데 같은 라인 사용하는중          1
# 351                    무난하게 쓰기좋은거같아용 세일할때사서 잘쓰고 있습니당ㅎㅎ          1
# 352               구매하고 꽤 됐네요.결광가득 넘버즈인 첨 써봤어요. 보습감 좋네요          1
# 353   200ml 무난한 용량입니다.\n무난하게 사용한 제품인데 재구매는 따로 안할것 같아요!          1
# 354  저는 복합성 수분부족한 피부 타입입니다.\n\n스킨은 정말 종류별로 여러개 갖고 있...          1
# 355  제가 생각했던 것보다 자극없이 순해서 좋았고 피부결 정돈이 되는 느낌이었어요 두 통...          1
# 358  넘버즈인은 진짜 다 좋은 거 같아요!! 광 나는건 솔직히 모르겠지만 약간 수분감이 ...          1
# 360  작년부터 핫했던 넘버즈인 숫자 시리즈 토너입니다~~\n\n몇번을 살까 고민고민하다가...          1
# 361  제품명에 [에센스 토너]라고 적혀 있는데\n사실상 토너 보다는 그냥 에센스 라고 봐...          1
# 362  ✨ 재구매 6통 중인 토너입니댱 ! 워낙 넘버즈인이 스킨케어로  유명해서 뭐 더 설...          1
# 363  넘버즈인 시트팩 쓰고 반해서 토너까지 산 사람입니다!!! 시트팩에 담겨있는 에센스 ...          1
# 364  너무 잘 쓰고 있어요\n발효성분 제게는 너무 잘 맞는 것 같고\n귀찮아서 앰플만 쓸...          1
# 365  넘버즈인 3번 결광토너 예상대로  좋네요.\n올영세일때  구입해서 한달정도 써보니 ...          1
# 366             아주 좋아요\n나중에 세일하면 하나더 사려고요 \n느무느무 촉촉합니당          1
# 368  순하구 근데 좀 무거운 느낌이긴해요 ! 피부 많이 건조할때 가을쯤 잘 쓸 것 같아오...          1
# 369  /1년 넘게 사용중/\n/토너중 유일한 재구매템/\n.\n한가지 토너를 이렇게 계속...          1
# 370  저는 발효성분에 대한 거부감은 커녕 너무 잘 맞는 피부라서 이거 3통인가 4통째 쓰...          1
# 371  T존은 지성이고 U존은 건성이라 건조한 부분에 토너 적신 화장솜으로 부드럽게 발라주...          1
# 372                    아침엔 4번~ 저녁엔 3번~ 자극없이 순하고, 촉촉해요.          1
# 373  저는 건성피부이며 여름에도 좀 촉촉한 기초제품을 찾는 편입니다. 참고해주세요~!\n...          1
# 374  넘버즈인 결광토너  처음 사용해보는데  느무느무좋으네요. 제형은  묽지않고 에센스와...          1
# 375  넘버즈인 3번 토너 너무 맘에들어용\n에센스 토너 제형 평소에도 너무 좋아하는데\n...          1
# 376        건성인 피부에 좋아요. 넝버즈인 제품력은 믿고 구매합니다. 재재구매  합니다.          1
# 377      매우 악건성인데 잘 쓰고 있음 끈적한 제형이 아니라 여러번 발라도 부담스럽지 않음          1
# 380  떨어질때가 다되서 미리 재구매 합니당\n몇통을 비웠는지 모르겠어요\n사용감도 만족스...          1
# 381  발효성분 안맞으면 어쩌나 고민고민하다 같은 번호 앰플이랑 같이 구매해서 사용 중인데...          1
# 382    보습 광채 탄력 모두 잡은 제품으로 고농축 에센스 같아요🫶🏻 재구매 의사 있습니다 ~          1
# 383            발효 에센스 토너라 고급지고 세안 후 바르면 건조함도 사라지고 촉촉해요          1
# 384  넘버즈인 토너만 사용하다가 결광에센스토너도 써보고 싶어서 세일안하지만 그냥 구매했어...          1
# 385  다른 토너는 바를때 대체로 엄청 묽은 느낌인데\n이 토너는 에센스 토너라 그런지 묽...          1
# Product name: [쿨링진정] 넘버즈인 1번 진정 맑게담은 청초토너 300ml 기획 (+1번 패드 10매 증정)
# Positive reviews:
#                                                   name  \
# 691  [쿨링진정] 넘버즈인 1번 진정 맑게담은 청초토너 300ml 기획 (+1번 패드 1...
#
#                                                 review  sentiment
# 691  무색 무취의 토너입니다!\n점성이 없는 제품이라 얇은 화장솜에 적셔서 피부 결 따라...          1
# Product name: [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무 클렌저 10ml 증정)
# Positive reviews:
#                                                   name  \
# 492  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 494  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 500  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 504  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 511  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 518  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 519  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 526  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 535  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 536  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 537  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 538  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 539  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 540  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 543  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 544  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 545  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 546  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 547  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 548  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 549  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 550  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 551  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 552  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 553  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 556  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 557  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 558  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 559  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 560  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 561  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 562  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 563  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 564  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 565  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 566  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 567  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 568  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 569  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 570  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 571  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 572  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 573  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 574  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 575  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 576  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 577  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 578  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 579  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 580  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 581  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 582  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 583  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 584  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
# 585  [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무...
#
#                                                 review  sentiment
# 492  안녕하세요 오늘은 라운드랩 브랜드의 스테디제품\n독도토너를 구입해 보았습니다\n\n...          1
# 494  디렉터파이님이 순하게 매일 각질제거 할 수 있고 수분감도 많다고 해서 샀는데,\n아...          1
# 500  !!!!포장 좀 줄여주세요 올리브영!!!!!\n독도 토너 제품은 좋아서 3번째 구매...          1
# 504  요건 증정용 사이즈에요. 독도 토너 궁금해서 한번 써봤는데 제 피부에는 잘 안 맞는...          1
# 511  매우매우 순한것 같아요\n다만 트러블에는 그렇게 좋진 않은 것 같아서 다른 거 써볼...          1
# 518  사람들이 많이 구입하길래 궁금했던 제품인데 드디어 사용해봅니다ㅎㅎ 며칠동안 사용해보...          1
# 519  자극이 전혀 없습니다. 민감성 피부인데 그냥 정제수인가 싶을 정도로 자극도 없고 화...          1
# 526     순한데 촉촉하진 않은것 같아요\n수부지 피부인데 보습용말고 닥토용으로 사용해야겠어요          1
# 535  유명세 때문에 구매했지만 그만한 효과는 없습니다\n\n보습, 수분감 이런 효과는 별...          1
# 536  무난하게 사용하기 좋아요\n작은용량은 여행용으로 사용하고,\n큰용량은 소분용기에 담...          1
# 537                유명해서 사봤는데 촉촉하니 나쁘지않은거같아요. 자극적이지 않네요          1
# 538            정말 자극 없이 순한 물토너에요! 손으로 촉촉하게 흡수시켜서 잘 썼어요          1
# 539              그냥 무난한듯 싶어요 촉촉하고 부담없고 그냥 막 쓰기 좋은거 같아요          1
# 540  마** 로즈 제품만 계속 썼었는데 올영데이때 보니 이 제품이 베스트라 한번 테스트겸...          1
# 543               겨울에는 복합성 여름에는 지성인 피부인데 일년내내쓰기 너무 좋아요          1
# 544  무난하게 쓰기 좋습니다. 양이 얼마 안 돼 금방 쓸 거 같아요. 향 거의 없어서 좋...          1
# 545          매일 이것만 쓰고 있어요 무난하게 쓰기 좋고 편하고 좋게 사용하고 있답니당          1
# 546  항상 쓰고 있어요. 다른 제품 써봤는데 자극이 되고 트러블이 올라와서 다시 구입해서...          1
# 547  스킨패드 용액으로 사용하려고 구매하였습니다~! 많이 쓸 것 같아서 대용령 기획세트가...          1
# 548          지성피부도  복합성 피부도  잘닦이는  스킨.    가격이  내렸으면 한다          1
# 549  순하고 너무 좋아요. 토너팩해도 되고 그냥 토너로만 사용해도 좋아요. 100ml 추...          1
# 550  🩷여름철 가볍게 닦토하기 좋아요 (기름기 X)\n🩷자극없이 순해요 (솔직히 물같음)...          1
# 551          자극없이 순해서 동생한테 추천했어요 남녀노소 안 가리고 쓰기 좋은거 같아욤          1
# 552  독도 라운드랩 얘기는 많이 들었었는데\n한번도 안써봐서 선뜻 손이 가지는 않았거든요...          1
# 553  정말 순하고 무난한 제품이라 누구나 사용하기 무난하지만 저는 잘 안맞았던 제품......          1
# 556   닥토로 아주 쓰기 좋아요 순하면서도 자극없이 보습도 되구 한통다쓰구 한통더 구입했습니다          1
# 557  1달정도 사용해봤는데 건성으로썬 별로 그냥 무난헀어요 나중에 다시 살것같진 않아요 ...          1
# 558           순하고 양 많은 토너 하면 독도토너만 생각나더라구요 세일하길래 구매했어오          1
# 559  ❤️\n보습 기능 없는 깔끔 물 토너.\n닦토 등 피부결 정리할 때 좋음.\n나는 ...          1
# 560               건성피부\n패드만 쓰다가 일단 한번 써보자해서 작은용량 주문했네요          1
# 561  독도토너 쓴지 2,3년 된 것 같아요! 중간에 토너 다른거 시도해봤지만 이것만큼 마...          1
# 562  수분감도 더해주는데 도움이 많이 되는 것 같네요. 자극도 없이 촉촉함을 살려주는것 ...          1
# 563  라운드랩 1025  독도토너가 스킨 용으로도 좋고 성분도 정말 순하고 팩으로도 쓰고...          1
# 564        클렌징하고 항상 닦토를 해주는데 깨끗하게 닦여서 좋아요 자극 없이 완전 순해요          1
# 565  유튜브나 sns에서 독도토너 극찬을 해서 신랑이랑 같이 쓰려고 대용량 구매했ㅇㅓ요ㅎ...          1
# 566  제가 기미랑 주근깨로 레이저를 하고나면 독도토너를 꼭 바르는데요!! 성분도, 가격도...          1
# 567          항상 닦는 토너로 사용하고 있습니다 아침에 가볍게 세안하고 닦아주면 좋아요          1
# 568         자극없이 순해서 민감성.피부에게 좋아요. 수분감도 충분하고, 향은 무향이에요          1
# 569  자극없이 순하고 물토너제형입니다! \n입구가 좁아서 흐르듯이 나올일은 없고 토너팩으...          1
# 570     제 인생 토너~~\n저같은 민감성 지성이신 분들은 이거 하나만 바르셔도 괜찮을듯ㅎㅎ          1
# 571  개좋아요 역시 믿고 쓰는 라운드랩\n공병만 다섯 개입니다.. 스프레이 ㅇ용기에 담아...          1
# 572       이 토너 너무 순해서 좋아요 \n두번째 구매중이며, 앞으로도 계속 구매할거같아여          1
# 573  아이 피부가 여드름 피부에 지성복합성 피부라 추천받아 샀는데 너무 좋다고 잘바르네요...          1
# 574  토너가 필요했는데 독도토너가 유명한 거 같아서 사봤어요! 아직 쓰던게 있어서  못써...          1
# 575  끈적임도 없고 트러블 피부도 사용허기 좋아요 정말 순하고 데일리로 사용하기 좋은거 ...          1
# 576  🫠녹는 여름 ...이 더위에 지친 피부를 진정 시키기에 \n토너 팩 만한 팩이 없는...          1
# 577  후기가 좋아보여서 간건데 나쁘지 않아서 두 통때 사다가 저한테 더 잘맞는 토너를 찾...          1
# 578  -발림성 완전 물\n-닥토,흡토,손토,팩토 아무거나 다 하기 좋다\n-물형태라 이것...          1
# 579  아직 남아있긴 하지만 토너를 다 써가고 있는 상황에 올영에 갔다가 독도 토너를 두 ...          1
# 580  제가 기미랑 주근깨로 레이저를 하고나면 독도토너를 꼭 바르는데요!! 한달 넘게 써도...          1
# 581  독도토너를 쓴 후론 성분이 정말 순하고 자극이 없어서 꾸준히 쓰고있는데요^^ 올리브...          1
# 582  올해도 레이저를 하면서 얼굴이 화끈하고 진정이 필요할땐 역시 독도 토너가 도움이 많...          1
# 583  라운드랩 독도 토너 한 달 후기입니다 \n\n한 달 동안 사용했는데 아직 증정용도 ...          1
# 584  진짜 몇통째 사는 건지 기억이 안나는 제품...\n몇년전부터 계속 사용하고 있는데 ...          1
# 585  더위가 몰려오는 요즘. 피부 손상이 심해지는 요즘,\n피부를 위해서 토너를 찾다가 ...          1
# Product name: [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리필+약콩판테놀크림1.5ml)
# Positive reviews:
#                                                   name  \
# 590  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 593  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 596  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 603  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 607  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 611  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 618  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 619  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 627  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 636  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 637  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 638  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 639  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 640  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 643  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 644  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 645  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 646  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 647  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 648  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 649  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 650  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 651  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 652  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 653  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 656  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 657  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 658  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 659  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 660  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 661  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 662  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 663  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 664  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 665  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 666  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 667  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 668  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 669  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 670  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 671  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 672  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 673  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 674  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 675  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 676  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 677  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 678  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 679  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 680  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 681  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 682  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 683  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 684  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 685  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
#
#                                                 review  sentiment
# 590  주변에서 독도 토너가 좋다는 이야기를 듣고 궁금한 마음에 구매해서 사용해 보게 되었...          1
# 593  안녕하세요 오늘은 라운드랩 브랜드의 스테디제품\n독도토너를 구입해 보았습니다\n\n...          1
# 596  디렉터파이님이 순하게 매일 각질제거 할 수 있고 수분감도 많다고 해서 샀는데,\n아...          1
# 603  !!!!포장 좀 줄여주세요 올리브영!!!!!\n독도 토너 제품은 좋아서 3번째 구매...          1
# 607  요건 증정용 사이즈에요. 독도 토너 궁금해서 한번 써봤는데 제 피부에는 잘 안 맞는...          1
# 611  매우매우 순한것 같아요\n다만 트러블에는 그렇게 좋진 않은 것 같아서 다른 거 써볼...          1
# 618  사람들이 많이 구입하길래 궁금했던 제품인데 드디어 사용해봅니다ㅎㅎ 며칠동안 사용해보...          1
# 619  자극이 전혀 없습니다. 민감성 피부인데 그냥 정제수인가 싶을 정도로 자극도 없고 화...          1
# 627     순한데 촉촉하진 않은것 같아요\n수부지 피부인데 보습용말고 닥토용으로 사용해야겠어요          1
# 636  무난하게 사용하기 좋아요\n작은용량은 여행용으로 사용하고,\n큰용량은 소분용기에 담...          1
# 637                유명해서 사봤는데 촉촉하니 나쁘지않은거같아요. 자극적이지 않네요          1
# 638            정말 자극 없이 순한 물토너에요! 손으로 촉촉하게 흡수시켜서 잘 썼어요          1
# 639              그냥 무난한듯 싶어요 촉촉하고 부담없고 그냥 막 쓰기 좋은거 같아요          1
# 640  마** 로즈 제품만 계속 썼었는데 올영데이때 보니 이 제품이 베스트라 한번 테스트겸...          1
# 643               겨울에는 복합성 여름에는 지성인 피부인데 일년내내쓰기 너무 좋아요          1
# 644  무난하게 쓰기 좋습니다. 양이 얼마 안 돼 금방 쓸 거 같아요. 향 거의 없어서 좋...          1
# 645          매일 이것만 쓰고 있어요 무난하게 쓰기 좋고 편하고 좋게 사용하고 있답니당          1
# 646  항상 쓰고 있어요. 다른 제품 써봤는데 자극이 되고 트러블이 올라와서 다시 구입해서...          1
# 647  스킨패드 용액으로 사용하려고 구매하였습니다~! 많이 쓸 것 같아서 대용령 기획세트가...          1
# 648          지성피부도  복합성 피부도  잘닦이는  스킨.    가격이  내렸으면 한다          1
# 649  순하고 너무 좋아요. 토너팩해도 되고 그냥 토너로만 사용해도 좋아요. 100ml 추...          1
# 650  🩷여름철 가볍게 닦토하기 좋아요 (기름기 X)\n🩷자극없이 순해요 (솔직히 물같음)...          1
# 651          자극없이 순해서 동생한테 추천했어요 남녀노소 안 가리고 쓰기 좋은거 같아욤          1
# 652  독도 라운드랩 얘기는 많이 들었었는데\n한번도 안써봐서 선뜻 손이 가지는 않았거든요...          1
# 653  정말 순하고 무난한 제품이라 누구나 사용하기 무난하지만 저는 잘 안맞았던 제품......          1
# 656   닥토로 아주 쓰기 좋아요 순하면서도 자극없이 보습도 되구 한통다쓰구 한통더 구입했습니다          1
# 657  1달정도 사용해봤는데 건성으로썬 별로 그냥 무난헀어요 나중에 다시 살것같진 않아요 ...          1
# 658           순하고 양 많은 토너 하면 독도토너만 생각나더라구요 세일하길래 구매했어오          1
# 659  ❤️\n보습 기능 없는 깔끔 물 토너.\n닦토 등 피부결 정리할 때 좋음.\n나는 ...          1
# 660               건성피부\n패드만 쓰다가 일단 한번 써보자해서 작은용량 주문했네요          1
# 661  독도토너 쓴지 2,3년 된 것 같아요! 중간에 토너 다른거 시도해봤지만 이것만큼 마...          1
# 662  수분감도 더해주는데 도움이 많이 되는 것 같네요. 자극도 없이 촉촉함을 살려주는것 ...          1
# 663  라운드랩 1025  독도토너가 스킨 용으로도 좋고 성분도 정말 순하고 팩으로도 쓰고...          1
# 664  아0아 제품 쓰다가 안 맞는 걱 같아서 또 유명한 제품인 독도토너 사용해보려고 구매...          1
# 665        클렌징하고 항상 닦토를 해주는데 깨끗하게 닦여서 좋아요 자극 없이 완전 순해요          1
# 666  유튜브나 sns에서 독도토너 극찬을 해서 신랑이랑 같이 쓰려고 대용량 구매했ㅇㅓ요ㅎ...          1
# 667  제가 기미랑 주근깨로 레이저를 하고나면 독도토너를 꼭 바르는데요!! 성분도, 가격도...          1
# 668          항상 닦는 토너로 사용하고 있습니다 아침에 가볍게 세안하고 닦아주면 좋아요          1
# 669         자극없이 순해서 민감성.피부에게 좋아요. 수분감도 충분하고, 향은 무향이에요          1
# 670  자극없이 순하고 물토너제형입니다! \n입구가 좁아서 흐르듯이 나올일은 없고 토너팩으...          1
# 671     제 인생 토너~~\n저같은 민감성 지성이신 분들은 이거 하나만 바르셔도 괜찮을듯ㅎㅎ          1
# 672  개좋아요 역시 믿고 쓰는 라운드랩\n공병만 다섯 개입니다.. 스프레이 ㅇ용기에 담아...          1
# 673       이 토너 너무 순해서 좋아요 \n두번째 구매중이며, 앞으로도 계속 구매할거같아여          1
# 674  아이 피부가 여드름 피부에 지성복합성 피부라 추천받아 샀는데 너무 좋다고 잘바르네요...          1
# 675  토너가 필요했는데 독도토너가 유명한 거 같아서 사봤어요! 아직 쓰던게 있어서  못써...          1
# 676  끈적임도 없고 트러블 피부도 사용허기 좋아요 정말 순하고 데일리로 사용하기 좋은거 ...          1
# 677  🫠녹는 여름 ...이 더위에 지친 피부를 진정 시키기에 \n토너 팩 만한 팩이 없는...          1
# 678  후기가 좋아보여서 간건데 나쁘지 않아서 두 통때 사다가 저한테 더 잘맞는 토너를 찾...          1
# 679  -발림성 완전 물\n-닥토,흡토,손토,팩토 아무거나 다 하기 좋다\n-물형태라 이것...          1
# 680  아직 남아있긴 하지만 토너를 다 써가고 있는 상황에 올영에 갔다가 독도 토너를 두 ...          1
# 681  제가 기미랑 주근깨로 레이저를 하고나면 독도토너를 꼭 바르는데요!! 한달 넘게 써도...          1
# 682  독도토너를 쓴 후론 성분이 정말 순하고 자극이 없어서 꾸준히 쓰고있는데요^^ 올리브...          1
# 683  올해도 레이저를 하면서 얼굴이 화끈하고 진정이 필요할땐 역시 독도 토너가 도움이 많...          1
# 684  라운드랩 독도 토너 한 달 후기입니다 \n\n한 달 동안 사용했는데 아직 증정용도 ...          1
# 685  진짜 몇통째 사는 건지 기억이 안나는 제품...\n몇년전부터 계속 사용하고 있는데 ...          1
# Product name: 아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml 증정)
# Positive reviews:
#                                                   name  \
# 398  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 424  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 436  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 437  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 438  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 439  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 440  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 441  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 442  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 444  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 445  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 446  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 447  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 449  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 450  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 451  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 454  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 455  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 456  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 457  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 458  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 459  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 461  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 462  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 463  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 464  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 465  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 466  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 467  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 468  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 469  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 470  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 471  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 472  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 474  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 475  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 476  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 477  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 478  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 479  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 480  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 481  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 482  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 483  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 484  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 485  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
#
#                                                 review  sentiment
# 398  아누아 어성초 토너 진짜 귀에 딱지가 얹을 정도로 이름을 너무 많이 들어봤어요! 이...          1
# 424            여드름 상처에 바르니 따갑다고 하는데 상처 없는 지성페부에는 자극없어요          1
# 436  좁쌀이 자주 올라와서 구입해본 아누아입니다. 받았던 토너 샘플 다 쓰고 본품 쓰고 ...          1
# 437  이모 선물로 제가 너무나 사랑하는 아누아 수딩 토너를 선물해드렸어요 ! 제가 아누아...          1
# 438  저는 이 제품을 아침에는 손으로 발라주고, 저녁에는 1/2 화장솜에 묻혀 토너팩으로...          1
# 439  진정효과에 탁월한 어성초 성분이 함유되어있으며 무매력이 매력인 토너입니다.\n수분감...          1
# 440  수분 팩으로 아침에 좋고요\n자극은 없는거 같고 엄청난 효과가 있는건 아니고\n수분...          1
# 441                   어성초성분이잘맞아서 몇통째사용하고있는데\n닦토하기도좋아요~          1
# 442  유명해서 구매해봤어요! 일단 용량이 음청 많아서 좋구 물토너라서 챱챱 하기 좋습니다...          1
# 444                 성분도좋고 촉촉해서 닦토로도잘쓰구있어요~\n만족하는제품입니다~          1
# 445        진정에좋고 순해요~ 용량도커서닦토로쓰기도좋아요~어성초성분이잘맞아서 잘쓰구있어요          1
# 446              아누아 어성초토너만 구매해요!\n토너용량도 많고, 배송도 빠르네요!          1
# 447  닦토로 사용을 했어요 향은 그냥 나쁘지 않은데 전 좋앗숩니다.. 처음에는 잘 모르겠...          1
# 449  후기가 조아서 중딩딸아이 주려고\n구매했어요 자극없는 제품인것\n같아서 만족합니다\...          1
# 450  아직 사용전인데\n 평소에 너무 궁금했던 브랜드라 항상 눈여겨봤었는데\n마침 세일하...          1
# 451  처음 사용했을 때는 피부가 열감이 느껴지고 적은 부분이 빨개지기도 해서 버려야겠다고...          1
# 454               항상구매하는 아누아토너입니다!\n이번 배송은 엄청 빨리도착했어요!          1
# 455   처음에 쓸떼 인생템이라 다섯통째쯤 되는거같은데 처음때만큼 효과가잇는거 같지 안달까???          1
# 456                무난하게 토너팩으로 막쓰기 좋은 제품인거 같아요\n세일때 사세요          1
# 457  그 유명한 아누아! 피지 분비가 많고 가끔 좁쌀이 올라오면 잘 안들어가서 오랫동안 ...          1
# 458  올영에서 할인하고 있어서 구매해온 토너에요. 엑소 수호토너로 유명합니다!! 아누아 ...          1
# 459  그나마 닦토 중에 젤 덜 건조했던 아이였던거 같네요\n리뷰 레고레고\n\n제 피부는...          1
# 461  민감한 건성피부인데 돌고 돌아 다시 정착😭\n점성 없는 물 제형의 토너\n물 제형의...          1
# 462  💕한달사용후기💕\n저는 피부에 크림이나 뭘 바르면 오히려 피부에 트러블이 나서 \n...          1
# 463       예민한 피부인데도 불구하고 너무 잘 맞아서 좋아요! 여름 철에 사용하면 최고👍👍          1
# 464  저는 민감성 여드름 피부에 파워 지성입니다\n\n우선 저는 한번도 스킨케어에서 정착...          1
# 465  여러 통째 사용중인 제품입니다! 민감성 피부인데 트러블 진정에도 좋고 물제형이라 가...          1
# 466  저한테는 자극 일도없어서 진짜 무난하게\n팩토로 사용하고 있어요~!\n필리밀리 1/...          1
# 467  워터리한 토너 찾으시면 추천드려요!!\n닦토 흡토 팩토에 모두 잘맞고 무향무색에 진...          1
# 468  진짜 팍팍써도 줄지를 않을정도로 양이 많아요ㅎㅎ 굿굿! 좁쌀에 좋고 진정에 좋아요!...          1
# 469  스캔의 다른 걸로 써보려다가 친구가 추천해줘서 구매했는데요. 어성초라 그런지 자극도...          1
# 470  한달 사용 리뷰입니다!\n\n쓰다보니 자극도 없고 좋았는데 다른 리뷰처럼 여드름이 ...          1
# 471  진짜 너무 좋아요 ⭐️\n피부가 여름에는 너무 예민해서 트러블도 올라오면서 화장도 ...          1
# 472  제가 제일 조아하는 토너에요! 순하고 자극적이지 않아요~ 예전에 사려고 알아보며 리...          1
# 474                    사용하고 나면 피부트러블 없이 순해서 좋은거 같아요~^^          1
# 475  진짜 2023년 올영에소 제일 잘 산 템이에요! 좁쌀은 잘 모르겠지만 쓰면 트러블 ...          1
# 476   토너 항상 이것만 씁니다\n벌써 5통째네요 ㅎㅎㅎ 트러블도 안나구 촉촉하고 너무 좋아요          1
# 477  이번 아누아 기획이 정말 좋은 것 같아요\n선크림에 토너패드 미니사이즈 토너까지 요...          1
# 478  한 다섯통째 ..? 쓰고있어요. 코로나때 피부 뒤집아지기 시작하고 아누아 어성초 괜...          1
# 479  아누아 1년 전에 써보고 계속 꾸준히 쓰는 중이에요\n순해서 좋고 아침 저녁으로 맨...          1
# 480  유튜브 보고 다른 토너 구매했다가  피부 뒤집어져..\n돈만 날리고 다시 돌아왔네요...          1
# 481  요즘 땀이 많이 나고 모자를 썼더니 이마에 가끔 트러블이 약하게 올라왔는데요 스킨이...          1
# 482  🌿인생토너 아누아🌿\n\n아누아 어성초 토너는 제가 정말 꾸준히 쓰고 있는 토너에요...          1
# 483  세일 좀 친다 할때마다 꼭 사서 쟁여놓고 쓰는 토너입니다. 이번엔 선크림이랑 토너패...          1
# 484  수술 후 잘 씻을 수 없어서 피부가 한번 뒤집혔었는데 요 토너 사용하면서 많이 진정...          1
# 485            자극없이 순해서 여러번 레이어드해서 발르면 피부가 촉촉해지는 기분이에요          1
# Product name: 아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# Positive reviews:
#                                           name  \
# 188  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 189  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 192  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 194  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 206  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 208  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 209  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 224  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 233  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 236  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 237  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 240  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 241  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 242  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 243  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 244  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 245  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 246  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 247  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 248  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 249  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 251  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 252  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 253  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 254  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 255  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 256  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 257  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 259  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 261  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 262  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 263  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 264  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 265  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 266  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 267  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 268  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 269  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 270  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 271  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 272  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 273  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 274  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 275  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 276  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 277  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 278  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 279  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 280  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 281  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 282  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 283  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 284  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 285  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
#
#                                                 review  sentiment
# 188  🍏퍼스널 컬러: 겨울 클리어\n🟰봄🌸영향을 많이 받은 겨울❄️클리어 타입\n\n🍏바...          1
# 189  🍏퍼스널 컬러: 겨울 클리어\n🟰봄🌸영향을 많이 받은 겨울❄️클리어 타입\n\n🍏바...          1
# 192      진정용으로 쓰고 있습니다. 원래는 수분용으로 썼었는데 여름에는 진정만으로 씁니다.          1
# 194  자극없이 순해요\n저는 수부지 타입인데 유트브에서 이 제품 많이 추천하길래 질러봤는...          1
# 206  그냥 제 최애 등극입니다..\n아비브가 평생 부자였으면 좋겠어요\n자고 일어났을때는...          1
# 208  패드랑 팩이 나쁘지 않아서 구매했어요. 정말 무난한 토너입니다. 막 그렇게 좋지도 ...          1
# 209                   여드름피부에 좋대서 쓰고잇습니다\n자극없이 순해서 좋습니다          1
# 224  일단.. 이거 쓰고 피부 뒤집어졌습니당 ..ㅎ T^T\n(*저는 어성초 성분이 들어...          1
# 233  후기처럼 좋은지는 모르겠어요.. 보습감도 안느껴지고, 물같은 제형이라서 여름에 가볍...          1
# 236  순하게 잘 쓰고 있는 토너입니다!\n수분토너가 아니라서 촉촉하지는 않아요\n진정토너...          1
# 237  다른제품 사용 하는데\n품절로 인해  직원추천받아 사용하였는데\n나름 좋아요\n진정...          1
# 240   무난한 토너 ㅎㅎㅎ\n결점 없이 무난해요 정말!\n하지만 저는 바이오더마로 돌아갑니다!          1
# 241  물제형 기초제품 잘 사용안하는데 여름되니까 모공막혀서 그런지 자꾸 피부트러블생겨서 ...          1
# 242  복합성이나 지성피부에 좋은 거 같은 아비브 어성초 토너! 두번째 구매인데 피부에 잘...          1
# 243  아비브 토너는 정유미 토너로 유명하고 요즘 수분 진정 보습이 잘 되어있는 토너를 못...          1
# 244  전 엄청난 극지성이여서 외출하고 오면 기름기가 엄청 나고 열감이 느껴져서 외출 후 ...          1
# 245  미스트는 뿌리면 건조해져서 저는 토너를 미스트 용기에 담아서 뿌리는데 꽤 괜찮네요!ㅋㅋㅋ          1
# 246  자극없고 순해요 촉촉한 물 제형이에요\n물제형이라 닦토도 좋고 팩하기도 편해요\n어...          1
# 247                   두번째 구매해서 사용해봅니다:) 무난하게 사용하기 좋아요!          1
# 248                   좋아요 효과좋고 부드럽게 밀착이 잘 되네요 좋습니다 굿굿귯          1
# 249  어성초 성분이 잘 맞는다면 누구나 순둥하게 잘 쓸 수 있는 제품 같아요! 다만 수부...          1
# 251  보습이나 진정이 이 제품의 가장 큰 정체성인 듯한데\n이 두가지 부분 모두 탁월하다...          1
# 252  저는 제품을 쓸때 같은 라인이거나 같이 쓰면 좋은 것 같은 상품이 있으면 함께 쓰는...          1
# 253  아비브 스팟 패드 카밍 터치, 아비브 어성초 팩 쓰는데 트러블 없이 잘 맞고 디렉터...          1
# 254  일단 제품은 살짝의 허브향같은게 나면서 과하지않아서 얼굴에 발라도 머리아프거나 기분...          1
# 255  민감성 여드름성 피부라 자극없는 토너가 필요했는데 어성초가 좋다~라는 소리를 듣고 ...          1
# 256  😖피부타입\n복합성, 민감성, 홍조 피부입니다. 평소에는 좁쌀여드름이 조금 나는 편...          1
# 257  원래 토너는 물제형만 썼는데 겨울철이라 보습이 부족한 것 같아서 이번에 아비브 토너...          1
# 259  토너를 사야해서 다양한 제품 중에 고민했는데 아비비가 성분이 젤 순해보이기도 하고 ...          1
# 261  한 달간 벌써 이 정도나 사용하다니🤣 시켜줘 아비브 명예사원👩‍🚒🧯🚒\n\n✔️저는...          1
# 262  아비브,,, 진짜 사랑해요\n\n마스크팩도 그렇고 토너도 진정에 너무 좋아요\n향은...          1
# 263  어성초 스킨 순하고 피부자극없이 좋아요\n오늘드림으로 구매했는데 1시간 내 배송와서...          1
# 264     오자마자 써보니 셍각보다시원한 느낌이 드네요?!다른거랑 고민했는데 느낌은 만족이에요          1
# 265  벌써 4통째? 쓴 것 같아요. 현재 5통째 같은데…ㅇㅅㅇ..\n예민하고 트러블이 자...          1
# 266  아비브 에센스를 잘 이용하고 있어서 토너를 구매하는 김에 같이 구매해봤습니다\n\n...          1
# 267  이 라인을 다 좋아해요 기획나오ㅏ서 좋고 끈적함 없어서 수부지도 추천합니다 어성초중...          1
# 268          토너패드랑 번갈아가면서 사용하는데 닦토로 해도 좋고 스킨팩 하기에도 좋아요          1
# 269               무난해요 속건조에 좋네요\n물제형이라 듬뿍 발라도 부담스럽지않아요          1
# 270         보습과 진정에 좋아 재구매했습니다\n건성이나 속건조 있는 피부에게 추천드려요          1
# 271  이 제품은 재구매를 너무 많이 해서 이제 리뷰 작성도 의미가 없을 정도🫠 동생이랑 ...          1
# 272  토너는 아비브만 써요! 피부가 예민한 편인데 진정에도 좋고 무엇보다 순해서 정말 좋...          1
# 273  올해가 너무 더워서 얼굴에 트러블이 더 나는건지 ㅜㅜ 계속 피부가 말썽이네요 진정용...          1
# 274  민감한 피부인데 무난하게 잘 사용하고 있어요\n완전 물제형이라 좋았어요 \n몇겹 레...          1
# 275  벌써 세통째 구입합니다.\n산뜻하면서 저자극적이여서 좋아요.\n두통째 쓰고나서 사러...          1
# 276  지성피부인데, 아주 잘 쓰고 있어요. 유수분 밸런스를 아주 잘 맞춰주는 편안한 토너...          1
# 277  흡수도 빠르고 스킨 부스터 용으로는 최고에요\n특히 진정감도 좋아서 여름철 쓰기 너...          1
# 278  대용량 기획품 스킨부스터\n\n말그대로 스킨첫단계 패드에부어서 사용해도되고\n스킨전...          1
# 279  가볍게 사용하기 좋은 토너입니다.\n닥토도 좋고, 스킨용으로도 좋아요.\n기본 피뷰...          1
# 280  아비부어성초카밍토너스킨부스터 \n(본품250ml+250ml리필)♡\n파격구성이라 무...          1
# 281  물제형이예요. 가볍고 산뜻한 제형이고 끈적임이 없어서 여름에 사용하기 좋았어요.\n...          1
# 282  아비브 어성초 좋다좋다 많이들었지만 다른 토너들 써보느라 자꾸 안사게됐는데 드디어 ...          1
# 283  아비브 어성초 토너 평생 함께하자🙄 \n\n✔️저는 유분감 있는 제형이랑 잘 맞지 ...          1
# 284  이 제품은 재구매를 너무 많이 해서 이제 리뷰 작성도 의미가 없을 정도🫠 동생이랑 ...          1
# 285      2통째 구매해서 사용중입니당~ 가벼우면서도 흡수력이 좋아서 산뜻하게 사용하기좋아요          1
# Product name: [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(350ML+350ML리필)
# Negative reviews:
#                                                  name  \
# 0   [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 1   [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 2   [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 3   [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 5   [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 6   [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 7   [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 8   [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 10  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 11  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 12  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 13  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 14  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 15  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 16  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 18  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 19  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 21  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 22  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 23  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 24  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 25  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 26  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 27  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# 28  [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(3...
# ...
# 632  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 633  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 634  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 635  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 641  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 642  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 654  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
# 655  [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리...
#
#                                                 review  sentiment
# 586  저는 건성에 촉촉한걸 발라야 하는 사람인데\n딱히 쓸만한 토너가 없어서 유명한 독도...          0
# 587  ★독도토너 한달사용 후기입니다★\n\n많은분들이 사용하여 궁금해서 사보게 된 독도토...          0
# 588  이고 쓰고 여드름이 엄청 올라오기 시작했어요ㅜㅜ\n다른제품으로 갈아타니 조금 가라앉...          0
# 589  상품은 좋은데 배송이 진짜... 무슨 박스 열었는데 토너 들어있는 상자가 개봉되어 ...          0
# 591  독도토너가 온라인상에서 하도 좋다고 유명하길래 써봤습니다.\n\n성분도 순하고 하도...          0
# 592  제 피부타입은 초예민에 극건성 피부입니다. ******참고하시고 읽어주세요*****...          0
# 594  ⭐️독도토너 후기 ⭐️\n\n예전에 독도토너를 써본 적이 있어서 자극이 없다는 걸 ...          0
# 595  원래 귀찮아서 리뷰 절대 안쓰는데 공익의 목적으로 씁니다 보습에 하나도 안좋고요 2...          0
# 597  그냥 스킨처럼 바르는데 그냥 엄청 좋지도 나쁘지도 않아서 계속 쓰고 있어요\n\n+...          0
# 598               저 구멍으로 제품 빠지면 어쩌시려고 배송을 이렇게 해주신 건가요?          0
# 599  순하다고 해서 구매했는데 저랑은 안맞나봐요... 피부 좋다는 말만 듣고 살았는데 이...          0
# 600  품평이좋아서 엄청기대한 토너\n바를때 순하고 좋은데 바르고 난후 점점 뭔가 얼굴이 ...          0
# 601  토너 하나 잘못 썼다고 피부가 이렇게 망가졌어요… 여드름 없는 피부였고 난다고해도 ...          0
# 602  배송도 일주일이상 걸리고 증정품같은것도 주겠다고 명시해서 추가구매를 유도한뒤 안보내...          0
# 604  새 제품인데 뚜껑 닫으려고 보니 뚜껑이 없습니다...\n500미리인데 다 사용할때까...          0
# 605  건조+ 민감 피부인데.. 본인이 좀 피부가 많이 예민하다 싶으면 꼭 테스트 해보세요...          0
# 606  저랑 너무 안 맞네요…\n유명해서 사봤지만 그래도 사람마다 피부는 다르니까ㅠㅠ\n어...          0
# 608                쓰고 피부 다 뒤집어짐......버렸음.......ㅝ부안예민한편          0
# 609  자극이 되는 느낌은 없는데 이 제품을 쓰고 피부가 뒤집어졌어요. 제가 예민한 피부여...          0
# 610  피부 민감한 분들은 함부로 안 사용하는 게 좋을 듯 쓰던 토너 다 떨어져서 급하게 ...          0
# 612  토너중에 거의 1등이다시피 유명해서 사본건데 그저그랬어요.\n기대를많이해서그런지 별...          0
# 613  독도토너가 그렇게 좋다고 하길래 구매했는데 사실 제 피부에선 좀 건조한 느낌이었어요...          0
# 614  친구네집에서 100ml 샘플 받아서 너무 좋아 새 상품을 구매하게됐는데요\n받자마자...          0
# 615  선물용으로 구매했습니다.\n생각보다 병도 작고, 양도 적어요. 그나마 50ml토너가...          0
# 616  제 피부가 예민하고 복합성 피부라 잘못바르면 피부에 바로 나타나는 피부에요!\n이거...          0
# 617  오랜만에 재구매 했는데\n사용할 때는 몰랐는데\n피부가 계속 안좋은게 토너 때문이였...          0
# 620  저만 그런건지는 모르겠는데 바르자마자 피부 빨갛게 올라와서 바로 버림... 솜으로 ...          0
# 621  뭘까요.. 그냥 닦토용으로 샀는데 처음 사용했을때는 정말 순해서 마음에 들었는데 이...          0
# 622  배송올때 토너가 조금 새서 왔네요. 조금밖에 안새긴해서 그냥 씁니다. 토너는 아직 ...          0
# 623  민감+복합성 피부입니다. \n\n순하다고 해서 한번 사봤는데 피부가 많이 예민한 타...          0
# 624  솔직히 다 좋은데 다른 사이트에서는 가격이 절반값이던데 물론 제가 조사해보지 않고 ...          0
# 625  전에... 5만원이상구매해서 받은 사은품 상자안에 이독도토너가 들어있어서 이제품을 ...          0
# 626  어성초토너를 계속 쓰다가 독도토너를 한 번 써봤는데 트러블 제어가 좀 어려운 느낌이...          0
# 628  많이들 쓰길래 구매해봤는데.\n솔직히 말하면..이걸 왜쓰지..? 하는 생각이 들었어...          0
# 629  닦토로 제일 유명하길래 저도 구매해봤는데 며칠 아침 저녁으로 써본 결과 저는 잘 안...          0
# 630  리뷰보고 구매했는데 저는 촉촉한것도 모르겠고 피부 진정되는지도 모르겠어요. 각질제거...          0
# 631             ㅠㅠ 나랑 넘 안 맞습니다…ㅠㅠ 진짜 좋다고 샀는데 많이 아쉽네요..          0
# 632                         이렇게 작은지 몰랐어욬ㅋㅋ 와 너무 작더라구요.          0
# 633            되게 유명해서 여러번 써봤지만 처음엔 괜찮다가 점점 아머 효과가 없어요          0
# 634  오랜만에 사용 했는데\n왠지 모르겠지만\n사용 하고나서 피부결이며\n피부 상태가 안...          0
# 635           민감하신 분들에게는 자극적일 거 같아요 저는 바르자마자 화하고 따가웟어요          0
# 641  독도 토너 쓰면 자극도 없고 순해서 좋아요! 그런데 빨리 쓴다는게 아쉽긴하네요...ㅠㅠㅠ          0
# 642  This is the first toner I've used and my pores...          0
# 654         음 딱히 효과를 못 봄 그냥저냥  나쁘진 않은데 비쌈 양도 생각 보다 적은듯          0
# 655  저한테는 안 맞아서 사용하고 좁쌀이 났어요ㅜ 잘맞는 사람은 되게 좋다고 해서 아쉬워요ㅜㅜ          0
# Product name: 아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml 증정)
# Negative reviews:
#                                                   name  \
# 386  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 387  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 388  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 389  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 390  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 391  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 392  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 393  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 394  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 395  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 396  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 397  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 399  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 400  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 401  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 402  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 403  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 404  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 405  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 406  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 407  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 408  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 409  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 410  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 411  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 412  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 413  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 414  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 415  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 416  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 417  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 418  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 419  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 420  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 421  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 422  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 423  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 425  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 426  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 427  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 428  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 429  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 430  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 431  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 432  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 433  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 434  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 435  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 443  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 448  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 452  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 453  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
# 473  아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml...
#
#                                                 review  sentiment
# 386  괜히 산 제품이예요 토너 외관이 깨끗한 느낌이고 사용 후 쫀 쫀한 느낌은 들지 않았...          0
# 387  제품마다 복불복인지 앞전에 구매했던건 한방냄새 나더니\n지금은 또 처음에 사용했던 ...          0
# 388  전에 쓰다가 다른걸로 갈아탔는데 왜 갈아탔는지가 기억이 안나서 다시 구매해 봤는데 ...          0
# 389         좁쌀에좋대서 산 제품인데 자잘한 좁쌀없애려고 샀다가 좁쌀 수십개 올라왔어요ㅠ          0
# 390  이 제품만 올리면 피부가 따끔거리고 마찰도 없는데 쓰라려서 못 쓰겠음. 순하다고 하...          0
# 391  엑소 누구지 암튼 연예인 어떤 분이 쓰시고 유명하기도 하고 유튜브에 뷰티 유튜버 분...          0
# 392  좁쌀에 좋다고 해서 샀는데 왠걸 이마에 좁쌀파티되었네요\n다시 원래피부 돌아가려고 ...          0
# 393           진짜 제가 민감성 피부여서 그런거같은데 너무 빨갛게 심하게 올라와요...          0
# 394                진짜 개똥같애요 좁쌀 사라지기는 무슨; 없던게 생겨서 깜짝놀랬네          0
# 395  아누아 어성초 토너 후기>>\n제 피부 타입은 건성에 민감성이에요. 건조해서 너무 ...          0
# 396  일단 옛날에도 엑소의 수호토너라고 해서 사용했는데 그때도 딱히 좋은 진정에 좋은느ㅁ...          0
# 397  아비브 어성초 팩이 무척 잘 맞았고 어성초 토너패드도 너~~ 무 잘 써서 어성초 잘...          0
# 399  제가 좁쌀여드름 때문에 정말 스트레스를 받고 있어요..\n그래서 유튜버분들이 극찬한...          0
# 400  저는 수분충전용+닦토 다 시험해봤어요\n제형은 물같은 제형이고 향도 거의 무향?\n...          0
# 401  피부가 안좋은편은 아니였는데 이거 쓰고 진짜 확안좋아지는게 눈에보여요 불긋불긋하게 ...          0
# 402  마녀꺼로 어성초 제품 처음 접하고 좋아서 기대하고 샀는데 왜 인기 많은지 모르겠음....          0
# 403  저는 사용하고 다음 날 피부에 유분기가 엄청 올라오면서\n가렵더니 피부가 뒤집어졌어...          0
# 404  어성초 토너 좋을 것 같아서 구매했는데\n처음엔 몰랐어요 이렇게 피부가 뒤집어질줄은...          0
# 405  하거 인기가 많아서 구매를 해봤는데 역시나 안맞는 사람이 있나봐요 ㅠㅠ 닦토 용도로...          0
# 406  * 불만족\n구매하기 전 참고했던 많은 리뷰들에서 부정적댓글을 보지 못했는데요. 솔...          0
# 407  진정에 좋다 해서 샀는데 제피부랑은 안맞았는지 이거 쓰면 다음날에 얼굴에 뭐 올라오...          0
# 408  엑소 수호땜에 알게되서 몇년째 쭉 쓰고 있었는데 유튜브에서 허위과장광고하는 업체라는...          0
# 409  제품은 죄가 없겠죠...\n어성초 성분 여드름에 좋다고 해서 새로 사봤는데\n제 피...          0
# 410  아누아 좋다고 유명해서 고민하고 비교하다가 구매해서 사용해봤는데 원래 피부 좋아서 ...          0
# 411  어...일단 결론부터 말하자면 제 피부는..박살이 났습니다😭\n제가 아누아 어성초 ...          0
# 412  자극이 하나도 없이 정말 순한 편이고\n딱히 근데 뛰어난 특징이 있다거나 하는 건 ...          0
# 413  사망여우 티비에서 보고 알았습니다\n허위과장광고 ..\n1위다 뭐다해서 여러개 구매...          0
# 414  유튜브나 방송에서 너무너무 좋다고 소문이 난 제품이라서 토너치고 많이 비싼 가격이였...          0
# 415  좁쌀때문에 구매🪴\n기대를 갖고 오늘드림으로 바로 구매했습니다.\n요즘에 알수없는 ...          0
# 416                    몇년째 쓰고있었는데 사망여우 보고 이제 안사려고요,,,,          0
# 417  제 피부타입은 건성이고 자극에 예민한 편이에요.\n기초케어는 스킨-로션-보습크림 이...          0
# 418        어성초는 원래 따가운건가요?\n이것도 피부에 바르면 엄청 따갑고 울긋불긋해져요          0
# 419  저는 여드름 피부에 계절 바뀌면 뒤집어지거 그날이면 뒤집어지고 피부가 좋은 날이 거...          0
# 420  요즘 스킨케어를 바꿔서 그런지 잠을 못 자서인지 확실하지는 않지만 갑자기 피부에 여...          0
# 421  유명하다길래 첫구매했어요\n많이 발라도 금방 흡수되고 매트해요\n촉촉함은 전혀 없어...          0
# 422  아누아 성분도 좋고 리뷰들듀 좋아서 어디한번 사보자 싶어서 구매하였습니다 피부가 예...          0
# 423  저는 어성초 토너를 이 기회에 처음 써봤는데 겨울엔 복합성,여름엔 지성(민감성)인 ...          0
# 425  지금까지 사용해본 토너 중에 제일 안 촉촉했어요ㅠㅠ 여름이라 만족하시는 분들도 계시...          0
# 426  평이너무좋아서 한번구매해봤습니다.\n그런데 평만큼 좋은건 모르겠네요\n그냥 보통 토...          0
# 427  얼마 안써서 인지는 잘모르겟지만 토너는 쓸만한데 요세 마스크를 써서 피부온도도 올라...          0
# 428  피부 진정 특히 좁쌀여드름에 좋다는 후기가 많길래\n가격도 용량대비 나쁘지 않아서 ...          0
# 429  이 제품은 맞는 사람에게는 인생템이고 아닌 사람에게는 트러블이 많이 올라오는 제품일...          0
# 430  좁쌀에 좋다고 해서 샀습니다\n반통 썼는데 아직 크게 효과는 못봤어요...더 써야 ...          0
# 431  리뷰도 많고 입소문이 엄청나서 품절된곳이 많아 힘들게(?) 구매하고 한달넘게 사용해...          0
# 432  복합성 피부인데 이 스킨으로 바꾸고 나서는 엄청 건조해졌어요...😢😢\n리뷰에 올라...          0
# 433  진짜 매번 드럭스토어에서 세일하는 제품 아무거나 쓰는 강철피분데 ㅠㅠㅠㅠ\n얘는 진...          0
# 434                 저랑은 안 맞아요ㅠ\n별로예요ㅜㅡ\n동생 줬어요\n비추천합니다          0
# 435  진정 성분이 많이 들었는데 제피부엔 안맞네요ㅜ바르고 나서 붉어지고 좁쌀여드름이 올라...          0
# 443  이거 사용해서 좁쌀 여드름이 안나고 화농성 여드름이 덜하고 이런 효과는 못 느꼈는데...          0
# 448  음..드라마틱한 효과는 모르겠어요 어찌보면 당연한걸수도..그냥 무난하게 쓰기 좋아요...          0
# 452  복합성 피부이고 3번결세럼&갈색병 썼다가 피부가 뒤집어졌어요^^... 발효성분 같은...          0
# 453  엄청 좋지도 안좋지도 않은 무난템인 것 같아요 ~~ 특별히 좋은 점을 모르겠어서 재...          0
# 473  유분감 1도 없는 토너 찾는 사람 들어와\n이거는 진짜 유분감 1도 없음\n이거 샘...          0
# Product name: 아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# Negative reviews:
#                                           name  \
# 186  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 187  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 190  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 191  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 193  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 195  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 196  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 197  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 198  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 199  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 200  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 201  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 202  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 203  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 204  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 205  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 207  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 210  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 211  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 212  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 213  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 214  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 215  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 216  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 217  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 218  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 219  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 220  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 221  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 222  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 223  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 225  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 226  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 227  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 228  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 229  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 230  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 231  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 232  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 234  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 235  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 238  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 239  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 250  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
# 258  아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정)
#
#                                                 review  sentiment
# 186  디파님이 민감성 피부에 추천해서 샀는데\n얼굴이 더 붉어져요......\n넘버x인 ...          0
# 187  디파님이 민감성 피부에 추천해서 샀는데\n얼굴이 더 붉어져요......\n넘버x인 ...          0
# 190  키*토너 쓰고 다써서 새로운거 써보고싶어서 순하다는 아비브토너 써봤는데 제피부에는 ...          0
# 191  저는 수부지 민감성 피부 타입인데 \n어성초가 저와 안 맞는지 피부가 뒤집어져서 몇...          0
# 193  저는 민감하고 아토피에다가 여드름이 조금 있는 피부라 아비브 유명하길래 구매를 해보...          0
# 195  - 여드름 피부 진정하려고 샀는데 바르고 잔 다음날부터 화농성 여드름이 더 커지고 ...          0
# 196  제 피부랑 안맞는지 쓰고나서 피지가 많아지고 여드름도 나는것 같아서 중단했어요 ㅠ ...          0
# 197  아비브 팩으로 입문하고 스킨은 처음 사서 써봤는데 팩이랑은 또 느낌이 달라요\n일단...          0
# 198  아비브 팩으로 입문하고 스킨은 처음 사서 써봤는데 팩이랑은 또 느낌이 달라요\n일단...          0
# 199  아비브 어성초 토너 좋다고하고  상품구성이  좋길래 구매했는데   하...우선  상...          0
# 200  어성초팩을 썼을때 다음날 피부상태가 넘 좋아서 어성초 성분믿고 구매했는데 피부 다 ...          0
# 201  박스가 너무 던져 박스가 심하게 찌그러져서 왔습니다. 도착한 토너는 열어보니 거품이...          0
# 202  유투버들이 하도 좋다해서.. 저는 정말 모르겠네요 \n실온에 두었는데 안에 내용물이...          0
# 203  음…. 다들 아비브 아비브.. 하는데 저는 정말 모르겠어요\n전에는 ㄴ버ㅈ인 사용하...          0
# 204       자극이심해요끈적이고 흡수되는 느낌이\n아니라 얼굴 표면위에 달라붙는 느낌 별로임          0
# 205  저만 그런건지는 모르겠는데 \n토너랑 앰플이랑 같이사서 구매했습니다.\n바르고 몇일...          0
# 207  사지마세요 \n어성초여서 좁쌀 잡으려고 사봤는데\n좁살 안 잡힙니다.... 저는 민...          0
# 210                       그냥 물같아요,.... 지성인분들이 쓰셔야할듯ㅜㅜㅜ          0
# 211  처음 사용했을 땐 광명 찾은 줄 알았습니다..\n저분자 히알루론산이 함유되어 있어\...          0
# 212  평소에 어성초가 잘맞기도 하고 디파님 추천으로 샀는데 얼굴이 더 붉어지고 자극이 돼...          0
# 213  평소에 어성초가 잘맞기도 하고 디파님 추천으로 샀는데 얼굴이 더 붉어지고 자극이 돼...          0
# 214  토너가 다 떨어져서 더블 기획할때 구매했는데 이거 사용하고 오랜만에 트러블이 올라왔...          0
# 215  백화점브랜드 키*토너쓰다가 디**파*님 유튜브보고 샀는데 글쎄요.. 마스크때문인지 ...          0
# 216  어성초랑 잘 맞는 사람이라 이 제품 라인 세트로 사봤는데 저는 딱히.. 여전히 속건...          0
# 217  으..저는 일단 기승전결 다 빼고 결론만 이야기 하자면..\n예민한 편도 아닌데.....          0
# 218  ㅜㅜ 리뷰 좋아서 구매했는데 이거 쓰고 피부 다 뒤집어졌어요 자극은 안 느껴지는데 ...          0
# 219  어으으믐. .아비브 어성초 팩이나 에센스는 진정에 무난 무난 꽤 괜찮아서 토너를 구...          0
# 220  피부가 뒤집어져서 고민하다가 올리브영에 가서 직원\n\n추천으로 어성초라인을 싹 다...          0
# 221  제품 용기를 다른 재질로 바꿨으면 좋겠네요. 약 50cm 높이에서 떨어졌는데 부숴져...          0
# 222            어...이거 제 피부에는 안맞는듯 \n고민하고 산건데 피부가 난리났어요          0
# 223  자극이 없다고 해서 샀는데...전 왜 이거를 쓰고 온갖 트러블이 다 났죠?ㅠㅠㅠㅠ원...          0
# 225  피부에 순하다고 해서 트러블을 잠재울 수 있는 줄알고 샀는데 트러블이 더 많이 생겨...          0
# 226  평소 트러블과 홍조가 많은 피부라 스킨리나 토너 선택할때 굉장히 신중히 택하는 편이...          0
# 227  ❣️3개월 이상 꾸준히 씀. 두 통 다비운 솔직후기입니다❣️\n👉🏻피부타입 - 악건...          0
# 228  자극은 없지만 수부지인 저에게 너무 별로였어요 ㅜㅜ 수부지 분들에게는 비추합니다 대...          0
# 229  어성초가 잘 맞을거라 기대하고 구매했는데 제 피부에는 유분기가 돌아서 잘 맞지 않네...          0
# 230   저랑은 잘 맞지 않아요\n트러블이 가라 앉지 않고 자꾸 더 생겨서 사용을 중단 했습니다          0
# 231     미끌미끌한 제형이라서 얼굴에 바를 때 좀 번들거렸어요 에센스보다는 별로인 거 같아요          0
# 232  평소 홍조와 예민한 피부를 가지고있어서 제품살때 주의하는편인데 이 제품 성분은 괜찮...          0
# 234   무향에 제형 다 좋은데 제 피부엔 안맞는거 같아요 .. 이틀 쓰고 피부 다 뒤집어졌어요          0
# 235   지건성 피부에요 저는 어성초성분이 피부에 안맞나봐요 바로 좁쌀 올라와서 중고나라 고고씽          0
# 238  저는 진짜 토너 정착 못해서 유명하다는거 다 써보고 랭킹순으류 해서 사거나 세일하는...          0
# 239     순하고 무난하긴한데 여드름에 효과를 보진 못했어요,, 저랑은 안맞는 것 같네용 ㅠㅠ          0
# 250         생각보다 촉촉함은 다 날라가더라구요 ㅠㅠ 그래도 피부가 좋아지길 기대하며,,          0
# 258  🫤 자극없이 촵촵 두드리기 좋은 물토너..이지만 효과는 딱히?\n\n👉🏻 리뷰어 피...          0

# %%
# TF-IDF Vectorizer 초기화
vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)

# %%
def extract_top_keywords_with_tfidf(grouped_reviews, n=10):
    # 각 그룹의 리뷰를 하나의 문서로 결합
    documents = [' '.join(group['review'].tolist()) for _, group in grouped_reviews]
    names = [name for name, _ in grouped_reviews]

    # TF-IDF 값 계산
    tfidf_matrix = vectorizer.fit_transform(documents)

    top_keywords = {}
    for i, name in enumerate(names):
        row = tfidf_matrix.getrow(i).toarray()[0]
        top_n_indices = row.argsort()[-n:][::-1]
        top_n_keywords = [vectorizer.get_feature_names_out()[idx] for idx in top_n_indices]
        top_keywords[name] = top_n_keywords

    return top_keywords

# %%
# 각 상품별 긍정 및 부정 리뷰에서 중요한 키워드 추출
positive_keywords = extract_top_keywords_with_tfidf(positive_grouped, n=5)
negative_keywords = extract_top_keywords_with_tfidf(negative_grouped, n=3)

# %%
print("Top Keywords for Positive Reviews:")
for name, keywords in positive_keywords.items():
    print(f"Product {name}: {', '.join(keywords)}")

print("\nTop Keywords for Negative Reviews:")
for name, keywords in negative_keywords.items():
    print(f"Product {name}: {', '.join(keywords)}")
# Out:
# Top Keywords for Positive Reviews:
# Product [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(350ML+350ML리필): 같아요, 어성초, 아누아, 토너, 있는
# Product [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (+화장솜 60매 증정): 다이브인, 토리든, 토너, 독도토너, 좋아요
# Product [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정): 넘버즈인, 에센스, 3번, 저는, 너무
# Product [쿨링진정] 넘버즈인 1번 진정 맑게담은 청초토너 300ml 기획 (+1번 패드 10매 증정): 무색, 토너여서, 이벤트로, 쟁입니다, 닦아줄
# Product [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무 클렌저 10ml 증정): 독도, 좋아요, 토너, 같아요, 많이
# Product [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리필+약콩판테놀크림1.5ml): 독도, 좋아요, 토너, 같아요, 많이
# Product 아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml 증정): 아누아, 토너, 어성초, 같아요, 너무
# Product 아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정): 아비브, 어성초, 토너를, 토너, 좋아요
#
# Top Keywords for Negative Reviews:
# Product [8월 올영픽/리필기획] 아누아 어성초 77 수딩 토너 350ML 리필 기획세트(350ML+350ML리필): 어성초, 피부가, 토너
# Product [8월올영픽/대용량기획] 토리든 다이브인 저분자 히알루론산 토너 500ml 기획 (+화장솜 60매 증정): 토리든, 너무, 배송
# Product [단독기획] 넘버즈인 3번 결광가득 에센스 토너 200ml (화장솜 증정): 발효, 피부, 너무
# Product [쿨링진정] 넘버즈인 1번 진정 맑게담은 청초토너 300ml 기획 (+1번 패드 10매 증정): 넘버즈인, 리뉴얼, 진짜
# Product [한정기획/대용량] 라운드랩 1025 독도 토너 500ml+200ml 기획(+소나무 클렌저 10ml 증정): 피부가, 저는, 너무
# Product [한정기획] 라운드랩 1025 독도 토너 대용량 리필기획 (300ml+300ml 리필+약콩판테놀크림1.5ml): 피부가, 너무, 쓰고
# Product 아누아 어성초 77 수딩 토너 350ml 기획(+토너40ml+패드2매+선크림10ml 증정): 어성초, 피부가, 토너
# Product 아비브 어성초 카밍 토너 스킨부스터 250ml 기획(+250ml 리필증정): 아비브, 저는, 같아요
